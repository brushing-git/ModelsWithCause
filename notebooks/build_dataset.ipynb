# %%
import numpy as np
import pandas as pd
from csr.intervention import build_intervention_big_dataset
from csr.markov_chain import build_markov_big_dataset

# %%
np.random.seed(123)

# %%
tr_size = 6250000
data, ps, params = build_intervention_big_dataset(6, tr_size=tr_size, seq_len=100, intervention_p=0.5)
# Out:
# 100%|██████████| 3125000/3125000 [14:15<00:00, 3654.86it/s]
# 100%|██████████| 3125000/3125000 [13:37<00:00, 3821.54it/s]

# %%
fn = "markov_chain-dice-100-intervention-training.txt"
np.savetxt(fn, data, fmt='%d', delimiter='', newline='')

fn = "markov_chain-dice-100-intervention-probabilities.csv"
df = pd.DataFrame(ps)
df.rename(columns={0: "Log Probabilities"})
df.to_csv(fn)

# Save the parameters as csv
fn = "markov_chain-dice-100-intervention-priors.csv"
df = pd.DataFrame(params[0])
df.rename(columns={0: "Priors"})
df.to_csv(fn)

fn = "markov_chain-dice-100-intervention-markov_mats.csv"
markov_mats = np.concatenate(params[1], axis=0)
df = pd.DataFrame(markov_mats)
df.to_csv(fn)

# %%
tr_size = 500000
data, ps, params = build_markov_big_dataset(6, tr_size=tr_size, seq_len=6)
# Out:
# 100%|██████████| 500000/500000 [00:28<00:00, 17689.47it/s]

# %%
fn = "markov_chain-dice-100-normal-training.txt"
np.savetxt(fn, data, fmt='%d', delimiter='', newline='')

fn = "markov_chain-dice-100-normal-probabilities.csv"
df = pd.DataFrame(ps)
df.rename(columns={0: "Log Probabilities"})
df.to_csv(fn)

# Save the parameters as csv
fn = "markov_chain-dice-100-normal-priors.csv"
df = pd.DataFrame(params[0])
df.rename(columns={0: "Priors"})
df.to_csv(fn)

# Save the Markov Mats
fn = "markov_chain-dice-100-normal-markov_mats.csv"
markov_mats = np.concatenate(params[1], axis=0)
df = pd.DataFrame(markov_mats)
df.to_csv(fn)
